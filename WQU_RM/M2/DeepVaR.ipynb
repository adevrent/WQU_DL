# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from arch import arch_model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Multivariate Portfolio VaR
#
# ![image.png](attachment:image.png)
